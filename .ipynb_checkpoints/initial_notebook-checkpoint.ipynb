# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import statsmodels.api as sm
from bs4 import BeautifulSoup
import time
import json
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.reset_option("display.max_rows", "display.max_columns")
from time import sleep
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_rows', 500)
pd.options.display.float_format = '{:.2f}'.format

# %%
def plot_variable_pairs(train, cols, hue=None):
    '''
    This function takes in a df, a list of cols to plot, and default hue=None 
    and displays a pairplot with a red regression line.
    '''
    plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.7}}
    sns.pairplot(train[cols], hue=hue, kind="reg",plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.1}})
    plt.show()

    
def plot_pairplot(train, cols, hue=None):
    '''
    Take in train df, list of columns to plot, and hue=None
    and display scatter plots and hists.
    '''
    sns.pairplot(train[cols], corner=True)
    plt.show()
    
    
    
def correlation_exploration(train, x_string, y_string):
    '''
    This function takes in a df, a string for an x-axis variable in the df, 
    and a string for a y-axis variable in the df and displays a scatter plot, the r-
    squared value, and the p-value. It explores the correlation between input the x 
    and y variables.
    '''
    r, p = stats.pearsonr(train[x_string], train[y_string])
    train.plot.scatter(x_string, y_string)
    plt.title(f"{x_string}'s Relationship with {y_string}")
    print(f'The p-value is: {p}. There is {round(p,3)}% chance that we see these results by chance.')
    print(f'r = {round(r, 2)}')
    plt.show()
    
def explore_univariate(df, variable):
    '''
    explore_univariate will take in a dataframe, and one feature or variable. It graphs a box plot and a distribution 
    of the single variable.
    '''
    #set figure size, font for axis ticks, and turns off gridlines.
    plt.figure(figsize=(30,10))
    sns.set(font_scale = 2)
    sns.set_style("whitegrid", {'axes.grid' : False})
    
    # boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(x=variable, data=df)
    plt.xlabel('')
    plt.title('Box Plot', fontsize=30)
    
    # distribution
    plt.subplot(1, 2, 2)
    sns.histplot(data=df, x=variable, element='step', kde=True, color='blue')
    plt.xlabel('')
    plt.ylabel('')
    plt.title('Distribution', fontsize=30)
    
    #title
    plt.suptitle(f'{variable}', fontsize = 45)
    plt.tight_layout()
    plt.show()
    
    
def explore_multivariate(train, target, cat_vars, quant_vars):
    '''
    '''
    plot_swarm_grid_with_color(train, target, cat_vars, quant_vars)
    plt.show()
    violin = plot_violin_grid_with_color(train, target, cat_vars, quant_vars)
    plt.show()
    pair = sns.pairplot(data=train, vars=quant_vars, hue=target)
    plt.show()    

def plot_swarm_grid_with_color(train, target, cat_vars, quant_vars):
    cols = len(cat_vars)
    for quant in quant_vars:
        _, ax = plt.subplots(nrows=1, ncols=cols, figsize=(16, 6), sharey=True)
        for i, cat in enumerate(cat_vars):
            sns.swarmplot(x=cat, y=quant, data=train, ax=ax[i], hue=target, palette="Set2")
            ax[i].set_xlabel('')
            ax[i].set_ylabel(quant)
            ax[i].set_title(cat)
        
def plot_violin_grid_with_color(train, target, cat_vars, quant_vars):
    cols = len(cat_vars)
    for quant in quant_vars:
        _, ax = plt.subplots(nrows=1, ncols=cols, figsize=(16, 4), sharey=True)
        for i, cat in enumerate(cat_vars):
            sns.violinplot(x=cat, y=quant, data=train, split=True, 
                           ax=ax[i], hue=target, palette="Set2")
            ax[i].set_xlabel('')
            ax[i].set_ylabel(quant)
            ax[i].set_title(cat) 

def plot_variable_pairs(train, cols, hue=None):
    '''
    This function takes in a df, a list of cols to plot, and default hue=None 
    and displays a pairplot with a red regression line.
    '''
    plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.4}}
    sns.pairplot(train[cols], hue=hue, kind="reg",plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.1}})
    sns.set(font_scale = .7)
    plt.show()

# %%
df = pd.read_excel('table6.xlsx', )

df
# Out:
#                                       Entity State              Ownership  \
# 0                           3000 Energy Corp    TX  Retail Power Marketer
# 1                            AP Holdings LLC    TX  Retail Power Marketer
# 2             ATG Clean Energy Holdings Inc.    TX  Retail Power Marketer
# 3                Accent Energy Holdings, LLC    TX  Retail Power Marketer
# 4                           Agera Energy LLC    TX  Retail Power Marketer
# 5               Alliance Power Company, LLC.    TX  Retail Power Marketer
# 6                 Ambit Energy Holdings, LLC    TX  Retail Power Marketer
# 7                             AmeriPower LLC    TX  Retail Power Marketer
# 8                   American Light and Power    TX  Retail Power Marketer
# 9                               Amigo Energy    TX  Retail Power Marketer
# 10                             Austin Energy    TX              Municipal
# 11              Bailey County Elec Coop Assn    TX            Cooperative
# 12                Bandera Electric Coop, Inc    TX            Cooperative
# 13               Bartlett Electric Coop, Inc    TX            Cooperative
# 14            Big Country Electric Coop, Inc    TX            Cooperative
# 15             Bluebonnet Electric Coop, Inc    TX            Cooperative
# 16             Bowie-Cass Electric Coop, Inc    TX            Cooperative
# 17                     Brilliant Energy, LLC    TX  Retail Power Marketer
# 18              Brooklet Energy Distribution    TX  Retail Power Marketer
# 19        Brownsville Public Utilities Board    TX              Municipal
# 20                               Bulb US LLC    TX  Retail Power Marketer
# 21              Central Texas Elec Coop, Inc    TX            Cooperative
# 22                  Champion Energy Services    TX  Retail Power Marketer
# 23                            Chariot Energy    TX  Retail Power Marketer
# 24            Cherokee County Elec Coop Assn    TX            Cooperative
# 25                    City of Brenham - (TX)    TX              Municipal
# 26                      City of Bryan - (TX)    TX              Municipal
# 27            City of College Station - (TX)    TX              Municipal
# 28                     City of Denton - (TX)    TX              Municipal
# 29                       City of Floresville    TX              Municipal
# 30                    City of Garland - (TX)    TX              Municipal
# 31                 City of Georgetown - (TX)    TX              Municipal
# 32                 City of Greenville - (TX)    TX              Municipal
# 33                    City of Lubbock - (TX)    TX              Municipal
# 34              City of New Braunfels - (TX)    TX              Municipal
# 35                City of San Antonio - (TX)    TX              Municipal
# 36                 City of San Marcos - (TX)    TX              Municipal
# 37                     City of Seguin - (TX)    TX              Municipal
# 38                   Clearview Electric Inc.    TX  Retail Power Marketer
# 39            Comanche County Elec Coop Assn    TX            Cooperative
# 40               Concho Valley Elec Coop Inc    TX            Cooperative
# 41                         Conservice Energy    TX  Retail Power Marketer
# 42              Constellation NewEnergy, Inc    TX  Retail Power Marketer
# 43               Cooke County Elec Coop Assn    TX            Cooperative
# 44             Deaf Smith Electric Coop, Inc    TX            Cooperative
# 45             Deep East Texas Elec Coop Inc    TX            Cooperative
# 46              Denton County Elec Coop, Inc    TX            Cooperative
# 47                    Direct Energy Services    TX  Retail Power Marketer
# 48                         ENGIE Retail, LLC    TX  Retail Power Marketer
# 49                       El Paso Electric Co    TX         Investor Owned
# 50                        Entergy Texas Inc.    TX         Investor Owned
# 51                            Entrust Energy    TX  Retail Power Marketer
# 52                 Evolve Retail Energy, LLC    TX  Retail Power Marketer
# 53         Farmers Electric Coop, Inc - (TX)    TX            Cooperative
# 54                Fayette Electric Coop, Inc    TX            Cooperative
# 55                  Frontier Utilities, Inc.    TX  Retail Power Marketer
# 56             Grayson-Collin Elec Coop, Inc    TX            Cooperative
# 57             Green Mountain Energy Company    TX  Retail Power Marketer
# 58              Greenbelt Electric Coop, Inc    TX            Cooperative
# 59                        GridPlus Texas Inc    TX  Retail Power Marketer
# 60                         Griddy Energy LLC    TX  Retail Power Marketer
# 61            Guadalupe Valley Elec Coop Inc    TX            Cooperative
# 62          HILCO Electric Cooperative, Inc.    TX            Cooperative
# 63            Hamilton County Elec Coop Assn    TX            Cooperative
# 64              Heart of Texas Electric Coop    TX            Cooperative
# 65                        Heritage Power LLC    TX  Retail Power Marketer
# 66              Houston County Elec Coop Inc    TX            Cooperative
# 67                    Hudson Energy Services    TX  Retail Power Marketer
# 68                  Iberdrola Solutions, LLC    TX  Retail Power Marketer
# 69                     Infinite Electric LLC    TX  Retail Power Marketer
# 70                         Infuse Energy LLC    TX  Retail Power Marketer
# 71         Jackson Electric Coop, Inc - (TX)    TX            Cooperative
# 72              Jasper-Newton Elec Coop, Inc    TX            Cooperative
# 73                               Just Energy    TX  Retail Power Marketer
# 74                  Karnes Electric Coop Inc    TX            Cooperative
# 75            Kerrville Public Utility Board    TX              Municipal
# 76               Lamar County Elec Coop Assn    TX            Cooperative
# 77            Lamb County Electric Coop, Inc    TX            Cooperative
# 78             Lea County Electric Coop, Inc    TX            Cooperative
# 79                       Liberty Power Corp.    TX  Retail Power Marketer
# 80             Lighthouse Electric Coop, Inc    TX            Cooperative
# 81               Lyntegar Electric Coop, Inc    TX            Cooperative
# 82                            MP2 Energy LLC    TX  Retail Power Marketer
# 83            Magic Valley Electric Coop Inc    TX            Cooperative
# 84                 Medina Electric Coop, Inc    TX            Cooperative
# 85          Mega Energy LP DBA Texans Energy    TX  Retail Power Marketer
# 86              Mid-South Electric Coop Assn    TX            Cooperative
# 87          MidAmerican Energy Services, LLC    TX  Retail Power Marketer
# 88             Navarro County Elec Coop, Inc    TX            Cooperative
# 89            Navasota Valley Elec Coop, Inc    TX            Cooperative
# 90              NextEra Energy Services, LLC    TX  Retail Power Marketer
# 91            North Plains Electric Coop Inc    TX            Cooperative
# 92               Nueces Electric Cooperative    TX            Cooperative
# 93                            Our Energy LLC    TX  Retail Power Marketer
# 94            Panola-Harrison Elec Coop, Inc    TX            Cooperative
# 95             Pedernales Electric Coop, Inc    TX            Cooperative
# 96                           Pogo Energy LLC    TX  Retail Power Marketer
# 97                       Pro Power Providers    TX  Retail Power Marketer
# 98                          Pulse Power, LLC    TX  Retail Power Marketer
# 99            Reliant Energy Retail Services    TX  Retail Power Marketer
# 100                           Rhythm Ops LLC    TX  Retail Power Marketer
# 101            Rio Grande Electric Coop, Inc    TX            Cooperative
# 102           Rita Blanca Electric Coop, Inc    TX            Cooperative
# 103           Rusk County Electric Coop, Inc    TX            Cooperative
# 104            Sam Houston Electric Coop Inc    TX            Cooperative
# 105           San Bernard Electric Coop, Inc    TX            Cooperative
# 106           San Patricio Electric Coop Inc    TX            Cooperative
# 107                   Smart Prepaid Electric    TX  Retail Power Marketer
# 108                SmartEnergy Holdings, LLC    TX  Retail Power Marketer
# 109                    SolarCity Corporation    TX       Behind the Meter
# 110           South Plains Electric Coop Inc    TX            Cooperative
# 111              Southern Federal Power, LLC    TX  Retail Power Marketer
# 112                 Southwest Arkansas E C C    TX            Cooperative
# 113           Southwest Texas Elec Coop, Inc    TX            Cooperative
# 114    Southwestern Electric Coop Inc - (NM)    TX            Cooperative
# 115           Southwestern Electric Power Co    TX         Investor Owned
# 116           Southwestern Public Service Co    TX         Investor Owned
# 117                         Spark Energy, LP    TX  Retail Power Marketer
# 118                          Stream SPE, LTD    TX  Retail Power Marketer
# 119                        Summer Energy LLC    TX  Retail Power Marketer
# 120                                  Sunnova    TX       Behind the Meter
# 121                              Sunrun Inc.    TX       Behind the Meter
# 122                TXU Energy Retail Co, LLC    TX  Retail Power Marketer
# 123                         Tara Energy, LLC    TX  Retail Power Marketer
# 124          Taylor Electric Coop Inc - (TX)    TX            Cooperative
# 125                        Texpo Power, L.P.    TX  Retail Power Marketer
# 126                     Tomorow Energy Corp.    TX  Retail Power Marketer
# 127       Tri-County Electric Coop, Inc (OK)    TX            Cooperative
# 128       Tri-County Electric Coop, Inc (TX)    TX            Cooperative
# 129                    TriEagle Energy, L.P.    TX  Retail Power Marketer
# 130             Trinity Valley Elec Coop Inc    TX            Cooperative
# 131                        US Retailers, LLC    TX  Retail Power Marketer
# 132  United Electric Coop Service Inc - (TX)    TX            Cooperative
# 133              Upshur Rural Elec Coop Corp    TX            Cooperative
# 134                   V247 Power Corporation    TX  Retail Power Marketer
# 135                   Value Based Brands LLC    TX  Retail Power Marketer
# 136                           Varsity Energy    TX  Retail Power Marketer
# 137                       Veteran Energy LLC    TX  Retail Power Marketer
# 138              Victoria Electric Coop, Inc    TX            Cooperative
# 139             Volt Electricity Provider LP    TX  Retail Power Marketer
# 140           Weatherford Mun Utility System    TX              Municipal
# 141            Wharton County Elec Coop, Inc    TX            Cooperative
# 142                 Windrose Power & Gas LLC    TX  Retail Power Marketer
# 143                   Wise Electric Coop Inc    TX            Cooperative
# 144   Wolverine Alternative Investments, LLC    TX  Retail Power Marketer
# 145           Wood County Electric Coop, Inc    TX            Cooperative
# 146                   XOOM Energy Texas, LLC    TX  Retail Power Marketer
# 147                        Young Energy, LLC    TX  Retail Power Marketer
#
#      Customers (Count)  Sales (Megawatthours)  Revenues (Thousands Dollars)  \
# 0                 3029                  34939                        4199.5
# 1                19223                 314407                       20393.0
# 2                18545                 335710                       16674.8
# 3                 6573                 100197                       13341.0
# 4                   34                      4                           0.7
# 5                 4897                  77652                        5130.0
# 6               409008                4827635                      547853.0
# 7                 1209                  22792                        2393.6
# 8                   39                     91                           5.6
# 80                   13.942289
# 81                    9.721182
# 82                   11.887216
# 83                    9.461101
# 84                   11.545561
# 85                    5.862404
# 86                   10.910894
# 87                   10.178067
# 88                   10.090278
# 89                   10.688417
# 90                   13.636892
# 91                   11.151408
# 92                   10.265706
# 93                    9.171228
# 94                    8.900438
# 95                   10.326788
# 96                    6.871225
# 97                   11.584158
# 98                   10.540945
# 99                   13.936369
# 100                  30.000000
# 101                  16.379457
# 102                   8.342386
# 103                  11.265359
# 104                  11.624552
# 105                  13.263463
# 106                  12.754322
# 107                  15.235101
# 108                  13.177083
# 109                  11.080000
# 110                   9.652235
# 111                   4.559328
# 112                  10.135597
# 113                  12.336648
# 114                  24.579439
# 115                  10.291964
# 116                  10.025935
# 117                  11.633749
# 118                  12.615325
# 119                  11.404246
# 120                  11.080000
# 121                  11.080000
# 122                  14.208789
# 123                  12.997728
# 124                  15.105930
# 125                   5.825909
# 126                  10.826211
# 127                  12.954454
# 128                   9.119506
# 129                  10.100161
# 130                  11.235423
# 131                  11.400232
# 132                   8.988559
# 133                  10.235402
# 134                   9.674909
# 135                   8.803559
# 136                   9.267291
# 137                  11.411637
# 138                  10.688617
# 139                   6.398291
# 140                   9.352228
# 141                  11.609596
# 142                   5.165863
# 143                   9.848689
# 144                   8.343501
# 145                  11.179606
# 146                  12.371089
# 147                  15.700788

# %% [markdown]
# - These numbers are from the year 2020.
# - The excel sheet was cleaned up through excel
# - There were 2 missing values in the average price columns that were imputed using the mean of the column

# %%
# Looking at specific data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity                        148 non-null    object
#  1   State                         148 non-null    object
#  2   Ownership                     148 non-null    object
#  3   Customers (Count)             148 non-null    int64
#  4   Sales (Megawatthours)         148 non-null    int64
#  5   Revenues (Thousands Dollars)  148 non-null    float64
#  6   Average Price (cents/kWh)     148 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 8.2+ KB

# %%
# Looking at the statistics of the columns to get a feel for the numbers

df.describe().transpose()
# Out:
#                               count       mean        std  min      25%  \
# Customers (Count)            148.00   76949.94  186658.71 7.00  6980.25
# Sales (Megawatthours)        148.00 1045438.43 2493754.52 1.00 87968.00
# Revenues (Thousands Dollars) 148.00  122477.41  330801.43 0.30  8835.57
# Average Price (cents/kWh)    148.00      11.08       3.00 4.56     9.79
#
#                                    50%       75%         max
# Customers (Count)             19333.00  51401.50  1376280.00
# Sales (Megawatthours)        279547.50 712820.75 19045888.00
# Revenues (Thousands Dollars)  30051.05  80259.80  2706190.10
# Average Price (cents/kWh)        10.91     12.08       30.00

# %%
# counting null values
df.isna().sum()
# Out:
# Entity                          0
# State                           0
# Ownership                       0
# Customers (Count)               0
# Sales (Megawatthours)           0
# Revenues (Thousands Dollars)    0
# Average Price (cents/kWh)       0
# dtype: int64

# %% [markdown]
# - No nulls to account for

# %% [markdown]
# - Takeaways
#     - average price in Texas for 2020 is 11.08 cents/Kwh
#     - average revenue in 2020 122 million in sales

# %% [markdown]
# # EDA

# %%
# sorting by revenue to see who has the top spot
df.sort_values(by=["Revenues (Thousands Dollars)", "Customers (Count)","Average Price (cents/kWh)"],ascending=False)[["Entity","Revenues (Thousands Dollars)", "Customers (Count)","Average Price (cents/kWh)" ]]
# 102           Rita Blanca Electric Coop, Inc                       2995.00
# 120                                  Sunnova                       2861.20
# 38                   Clearview Electric Inc.                       2498.30
# 7                             AmeriPower LLC                       2393.60
# 78             Lea County Electric Coop, Inc                       2113.00
# 112                 Southwest Arkansas E C C                       1988.30
# 20                               Bulb US LLC                       1963.60
# 107                   Smart Prepaid Electric                        557.30
# 136                           Varsity Energy                        406.00
# 52                 Evolve Retail Energy, LLC                        367.80
# 127       Tri-County Electric Coop, Inc (OK)                        321.40
# 126                     Tomorow Energy Corp.                        266.00
# 144   Wolverine Alternative Investments, LLC                        177.80
# 114    Southwestern Electric Coop Inc - (NM)                         26.30
# 108                SmartEnergy Holdings, LLC                         25.30
# 97                       Pro Power Providers                         11.70
# 8                   American Light and Power                          5.60
# 4                           Agera Energy LLC                          0.70
# 100                           Rhythm Ops LLC                          0.30
#
#      Customers (Count)  Average Price (cents/kWh)
# 122            1376280                      14.21
# 99             1311845                      13.94
# 35              780488                      10.74
# 47              604160                      12.57
# 50              410753                       9.89
# 6               409008                      11.35
# 95              334725                      10.33
# 131             268711                      11.40
# 10              457272                      10.56
# 57              314732                      13.42
# 118             237922                      12.62
# 90              205462                      13.64
# 46              243529                       9.80
# 73              190411                      12.88
# 49              297495                      12.06
# 22              148142                      10.95
# 42              147719                      11.41
# 116             214908                      10.03
# 115             152519                      10.29
# 129             133907                      10.10
# 9                94428                      13.20
# 128             101393                       9.12
# 83              110393                       9.46
# 135             127181                       8.80
# 55               85433                      12.15
# 15               91614                      10.45
# 98               71593                      10.54
# 61               80023                      10.11
# 104              73497                      11.62
# 130              67641                      11.24
# 132              76403                       8.99
# 53               62247                      11.57
# 33               92596                      10.15
# 93               57337                       9.17
# 56               59183                      11.44
# 30               65672                      10.22
# 51               49595                      11.32
# 28               50802                      13.11
# 146              43031                      12.37
# 26               53200                       9.92
# 117              38249                      11.63
# 19               45827                      10.98
# 133              41825                      10.24
# 134              39805                       9.67
# 147              34641                      15.70
# 110              45717                       9.65
# 27               40486                      12.94
# 92               37782                      10.27
# 34               40204                       9.75
# 105              29153                      13.26
# 16               33625                      11.77
# 45               39551                       9.98
# 70               37937                      10.47
# 12               32403                      10.96
# 21               35784                      11.16
# 23               31931                      10.36
# 86               29482                      10.91
# 145              32924                      11.18
# 48               27015                       9.94
# 62               23353                      10.37
# 84               27439                      11.55
# 41               35315                       9.85
# 125              37318                       5.83
# 69               27406                      10.95
# 31               25240                      14.55
# 123              21630                      13.00
# 119              24132                      11.40
# 60               25463                       8.25
# 138              20308                      10.69
# 79               19076                      13.80
# 103              19210                      11.27
# 143              18088                       9.85
# 124              15663                      15.11
# 72               20565                      11.55
# 24               19694                      10.66
# 64               17024                       9.00
# 29               13960                      11.35
# 66               20502                      12.54
# 74               16793                       9.72
# 88               15666                      10.09
# 75               19443                       8.47
# 63               17942                      10.60
# 89               18275                      10.69
# 36               21415                       9.47
# 43               14449                      10.99
# 54               13247                      14.46
# 32               13410                      13.50
# 1                19223                       6.49
# 17               11139                      11.03
# 140              12895                       9.35
# 71               14894                      11.13
# 13                9035                      10.91
# 137              10051                      11.41
# 40               11266                      13.51
# 2                18545                       4.97
# 76               12099                      10.73
# 101               8749                      16.38
# 106               9326                      12.75
# 3                 6573                      13.31
# 39                6813                      11.88
# 18               10657                       9.94
# 142              15351                       5.17
# 87                7036                      10.18
# 68                8987                      12.94
# 94                9091                       8.90
# 96               13628                       6.87
# 14                8995                      12.79
# 81                8440                       9.72
# 82                8217                      11.89
# 37                7164                      10.66
# 139              10982                       6.40
# 67                5468                       9.92
# 109               7255                      11.08
# 141               5391                      11.61
# 25                5873                       8.76
# 111               5657                       4.56
# 85                9325                       5.86
# 65                5072                       7.89
# 5                 4897                       6.61
# 121               2775                      11.08
# 44                5249                       8.69
# 113               5644                      12.34
# 58                3770                      16.59
# 0                 3029                      12.02
# 59                2697                       9.27
# 91                3056                      11.15
# 80                3799                      13.94
# 77                2748                       9.75
# 11                3355                      11.79
# 102               2802                       8.34
# 120               1401                      11.08
# 38                1437                      17.18
# 7                 1209                      10.50
# 78                1785                       8.65
# 112               1038                      10.14
# 20                2974                       5.12
# 107                374                      15.24
# 136                761                       9.27
# 52                 258                       8.79
# 127                203                      12.95
# 126                176                      10.83
# 144                100                       8.34
# 114                 13                      24.58
# 108                 14                      13.18
# 97                 133                      11.58
# 8                   39                       6.15
# 4                   34                      17.50
# 100                  7                      30.00

# %%
#let's split our data using my train_validate_test function, and check our train, validate, and test shapes. Our target is Average Price (cents/kWh).
def train_validate_test(df, target):
    '''
    this function takes in a dataframe and splits it into 3 samples, 
    a test, which is 20% of the entire dataframe, 
    a validate, which is 24% of the entire dataframe,
    and a train, which is 56% of the entire dataframe. 
    It then splits each of the 3 samples into a dataframe with independent variables
    and a series with the dependent, or target variable. 
    The function returns train, validate, test sets and also another 3 dataframes and 3 series:
    X_train (df) & y_train (series), X_validate & y_validate, X_test & y_test. 
    '''
    # split df into test (20%) and train_validate (80%)
    train_validate, test = train_test_split(df, test_size=.2, random_state=123)

    # split train_validate off into train (70% of 80% = 56%) and validate (30% of 80% = 24%)
    train, validate = train_test_split(train_validate, test_size=.3, random_state=123)

        
    # split train into X (dataframe, drop target) & y (series, keep target only)
    X_train = train.drop(columns=[target])
    y_train = train[target]
    
    # split validate into X (dataframe, drop target) & y (series, keep target only)
    X_validate = validate.drop(columns=[target])
    y_validate = validate[target]
    
    # split test into X (dataframe, drop target) & y (series, keep target only)
    X_test = test.drop(columns=[target])
    y_test = test[target]
    
    return train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test

target = 'Average Price (cents/kWh)'
train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test = train_validate_test(df, target)
train.shape, validate.shape, test.shape
# Out:
# ((82, 7), (36, 7), (30, 7))

# %%
def get_object_cols(df):
    '''
    This function takes in a dataframe and identifies the columns that are object types
    and returns a list of those column names. 
    '''
    # create a mask of columns whether they are object type or not
    mask = np.array(df.dtypes == "object")

        
    # get a list of the column names that are objects (from the mask)
    object_cols = df.iloc[:, mask].columns.tolist()
    
    return object_cols

# %%
def get_numeric_X_cols(X_train, object_cols):
    '''
    takes in a dataframe and list of object column names
    and returns a list of all other columns names, the non-objects. 
    '''
    numeric_cols = [col for col in X_train.columns.values if col not in object_cols]
    
    return numeric_cols

# %%
def min_max_scale(X_train, X_validate, X_test, numeric_cols):
    '''
    this function takes in 3 dataframes with the same columns, 
    a list of numeric column names (because the scaler can only work with numeric columns),
    and fits a min-max scaler to the first dataframe and transforms all
    3 dataframes using that scaler. 
    it returns 3 dataframes with the same column names and scaled values. 
    '''
    # create the scaler object and fit it to X_train (i.e. identify min and max)
    # if copy = false, inplace row normalization happens and avoids a copy (if the input is already a numpy array).


    scaler = MinMaxScaler(copy=True).fit(X_train[numeric_cols])

    #scale X_train, X_validate, X_test using the mins and maxes stored in the scaler derived from X_train. 
    # 
    X_train_scaled_array = scaler.transform(X_train[numeric_cols])
    X_validate_scaled_array = scaler.transform(X_validate[numeric_cols])
    X_test_scaled_array = scaler.transform(X_test[numeric_cols])

    # convert arrays to dataframes
    X_train_scaled = pd.DataFrame(X_train_scaled_array, 
                                  columns=numeric_cols).\
                                  set_index([X_train.index.values])

    X_validate_scaled = pd.DataFrame(X_validate_scaled_array, 
                                     columns=numeric_cols).\
                                     set_index([X_validate.index.values])

    X_test_scaled = pd.DataFrame(X_test_scaled_array, 
                                 columns=numeric_cols).\
                                 set_index([X_test.index.values])

    
    return X_train_scaled, X_validate_scaled, X_test_scaled

# %%
#let's scale our data using the min_max_scale function. Not scaling the target. 
#since I used z-score to weed out outliers, this should work fine.
obj_cols = get_object_cols(df)
num_cols = get_numeric_X_cols(X_train, obj_cols)
X_train_scaled, X_validate_scaled, X_test_scaled = min_max_scale(X_train, X_validate, X_test, num_cols)

# %%
def get_util_heatmap(train):
    plt.figure(figsize=(8,12))
    heatmap = sns.heatmap(df.corr()[['Average Price (cents/kWh)']].sort_values(by='Average Price (cents/kWh)', ascending=False), vmin=-.5, vmax=.5, annot=True)
    heatmap.set_title('Feautures Correlating with Average Price (cents/kWh)')
    
    return heatmap

# %%
get_util_heatmap(train)
# Out:
# <AxesSubplot:title={'center':'Feautures Correlating with Average Price (cents/kWh)'}>

# %%
# univariate study
univariate_study = ['Customers (Count)','Sales (Megawatthours)','Revenues (Thousands Dollars)','Average Price (cents/kWh)']

for i in univariate_study:
    explore_univariate(train, i)
    print(f'Summary Statistics for {i}\n{train[i].describe()}')
# Out:
# Summary Statistics for Customers (Count)
# count        82.00
# mean      73454.94
# std      173062.28
# min         100.00
# 25%        7356.50
# 50%       21097.50
# 75%       58721.50
# max     1311845.00
# Name: Customers (Count), dtype: float64
# Summary Statistics for Sales (Megawatthours)
# count         82.00
# mean      964284.26
# std      2207175.44
# min          101.00
# 25%       100352.50
# 50%       312843.50
# 75%       920446.00
# max     17200467.00
# Name: Sales (Megawatthours), dtype: float64
# Summary Statistics for Revenues (Thousands Dollars)
# count        82.00
# mean     114235.72
# std      296721.81
# min          11.70
# 25%       11194.80
# 50%       31847.95
# 75%      101132.50
# max     2397120.50
# Name: Revenues (Thousands Dollars), dtype: float64
# Summary Statistics for Average Price (cents/kWh)
# count   82.00
# mean    10.96
# std      2.23
# min      4.56
# 25%      9.75
# 50%     10.96
# 75%     12.12
# max     17.18
# Name: Average Price (cents/kWh), dtype: float64
